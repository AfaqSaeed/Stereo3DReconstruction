# %%
import cv2
from numpy import *
import numpy as np
import os
import random

# %%
pathR = "D:/Downloads/GL010036/"
pathL = "../left/"

pathStR = "../both/right/"
pathStL = "../both/left/"

pathTestR = "D:/Downloads/GL010036/Test/"

calibParams = "D:Downloads/GL010036/Calib_Params/"

# %%
cap1 = cv2.VideoCapture("D:/Downloads/GX010036.MP4")
ret = True
i = 1
folder ="D:/Downloads/GL010036/"

if os.path.exists("D:/Downloads/GL010036/"):
    pass
else:
    os.mkdir("D:/Downloads/GL010036/")
length = int(cap1.get(cv2.CAP_PROP_FRAME_COUNT))

print(length)


while i <length :
    
    ret, image = cap1.read()
    i=i+1
    if image is None:
        continue
        
    
    if i%30==0:
        if cv2.imwrite(folder+f"{i}.png",image):
            print("Frame No : "+str(i) +f" Successfully written to {folder}")
# Out:
# 9255
# Frame No : 90 Successfully written to D:/Downloads/GL010036/
# Frame No : 120 Successfully written to D:/Downloads/GL010036/
# Frame No : 150 Successfully written to D:/Downloads/GL010036/
# Frame No : 180 Successfully written to D:/Downloads/GL010036/
# Frame No : 210 Successfully written to D:/Downloads/GL010036/
# Frame No : 240 Successfully written to D:/Downloads/GL010036/
# Frame No : 270 Successfully written to D:/Downloads/GL010036/
# Frame No : 300 Successfully written to D:/Downloads/GL010036/
# Frame No : 330 Successfully written to D:/Downloads/GL010036/
# Frame No : 360 Successfully written to D:/Downloads/GL010036/
# Frame No : 390 Successfully written to D:/Downloads/GL010036/
# Frame No : 420 Successfully written to D:/Downloads/GL010036/
# Frame No : 450 Successfully written to D:/Downloads/GL010036/
# Frame No : 480 Successfully written to D:/Downloads/GL010036/
# Frame No : 510 Successfully written to D:/Downloads/GL010036/
# Frame No : 540 Successfully written to D:/Downloads/GL010036/
# Frame No : 570 Successfully written to D:/Downloads/GL010036/
# Frame No : 600 Successfully written to D:/Downloads/GL010036/
# Frame No : 630 Successfully written to D:/Downloads/GL010036/
# Frame No : 660 Successfully written to D:/Downloads/GL010036/
# Frame No : 690 Successfully written to D:/Downloads/GL010036/
# Frame No : 720 Successfully written to D:/Downloads/GL010036/
# Frame No : 750 Successfully written to D:/Downloads/GL010036/
# Frame No : 780 Successfully written to D:/Downloads/GL010036/
# Frame No : 810 Successfully written to D:/Downloads/GL010036/
# Frame No : 840 Successfully written to D:/Downloads/GL010036/
# Frame No : 870 Successfully written to D:/Downloads/GL010036/
# Frame No : 900 Successfully written to D:/Downloads/GL010036/
# Frame No : 930 Successfully written to D:/Downloads/GL010036/
# Frame No : 960 Successfully written to D:/Downloads/GL010036/
# Frame No : 990 Successfully written to D:/Downloads/GL010036/
# Frame No : 1020 Successfully written to D:/Downloads/GL010036/
# Frame No : 1050 Successfully written to D:/Downloads/GL010036/
# Frame No : 1080 Successfully written to D:/Downloads/GL010036/
# Frame No : 1110 Successfully written to D:/Downloads/GL010036/
# Frame No : 1140 Successfully written to D:/Downloads/GL010036/
# Frame No : 1170 Successfully written to D:/Downloads/GL010036/
# Frame No : 1200 Successfully written to D:/Downloads/GL010036/
# Frame No : 1230 Successfully written to D:/Downloads/GL010036/
# Frame No : 1260 Successfully written to D:/Downloads/GL010036/
# Frame No : 1290 Successfully written to D:/Downloads/GL010036/
# Frame No : 1320 Successfully written to D:/Downloads/GL010036/
# Frame No : 1350 Successfully written to D:/Downloads/GL010036/
# Frame No : 1380 Successfully written to D:/Downloads/GL010036/
# Frame No : 1410 Successfully written to D:/Downloads/GL010036/
# Frame No : 1440 Successfully written to D:/Downloads/GL010036/
# Frame No : 1470 Successfully written to D:/Downloads/GL010036/
# Frame No : 1500 Successfully written to D:/Downloads/GL010036/
# Frame No : 1530 Successfully written to D:/Downloads/GL010036/
# Frame No : 1560 Successfully written to D:/Downloads/GL010036/
# Frame No : 1590 Successfully written to D:/Downloads/GL010036/
# Frame No : 1620 Successfully written to D:/Downloads/GL010036/
# Frame No : 1650 Successfully written to D:/Downloads/GL010036/
# Frame No : 1680 Successfully written to D:/Downloads/GL010036/
# Frame No : 1710 Successfully written to D:/Downloads/GL010036/
# Frame No : 1740 Successfully written to D:/Downloads/GL010036/
# Frame No : 1770 Successfully written to D:/Downloads/GL010036/
# Frame No : 1800 Successfully written to D:/Downloads/GL010036/
# Frame No : 1830 Successfully written to D:/Downloads/GL010036/
# Frame No : 1860 Successfully written to D:/Downloads/GL010036/
# Frame No : 1890 Successfully written to D:/Downloads/GL010036/
# Frame No : 1920 Successfully written to D:/Downloads/GL010036/
# Frame No : 1950 Successfully written to D:/Downloads/GL010036/
# Frame No : 1980 Successfully written to D:/Downloads/GL010036/
# Frame No : 2010 Successfully written to D:/Downloads/GL010036/
# Frame No : 2040 Successfully written to D:/Downloads/GL010036/
# Frame No : 2070 Successfully written to D:/Downloads/GL010036/
# Frame No : 2100 Successfully written to D:/Downloads/GL010036/
# Frame No : 2130 Successfully written to D:/Downloads/GL010036/
# Frame No : 2160 Successfully written to D:/Downloads/GL010036/
# Frame No : 2190 Successfully written to D:/Downloads/GL010036/
# Frame No : 2220 Successfully written to D:/Downloads/GL010036/
# Frame No : 2250 Successfully written to D:/Downloads/GL010036/
# Frame No : 2280 Successfully written to D:/Downloads/GL010036/
# Frame No : 2310 Successfully written to D:/Downloads/GL010036/
# Frame No : 2340 Successfully written to D:/Downloads/GL010036/
# Frame No : 2370 Successfully written to D:/Downloads/GL010036/
# Frame No : 2400 Successfully written to D:/Downloads/GL010036/
# Frame No : 2430 Successfully written to D:/Downloads/GL010036/
# Frame No : 2460 Successfully written to D:/Downloads/GL010036/
# Frame No : 2490 Successfully written to D:/Downloads/GL010036/
# Frame No : 2520 Successfully written to D:/Downloads/GL010036/
# Frame No : 2550 Successfully written to D:/Downloads/GL010036/
# Frame No : 2580 Successfully written to D:/Downloads/GL010036/
# Frame No : 2610 Successfully written to D:/Downloads/GL010036/
# Frame No : 2640 Successfully written to D:/Downloads/GL010036/
# Frame No : 2670 Successfully written to D:/Downloads/GL010036/
# Frame No : 2700 Successfully written to D:/Downloads/GL010036/
# Frame No : 2730 Successfully written to D:/Downloads/GL010036/
# Frame No : 2760 Successfully written to D:/Downloads/GL010036/
# Frame No : 2790 Successfully written to D:/Downloads/GL010036/
# Frame No : 2820 Successfully written to D:/Downloads/GL010036/
# Frame No : 2850 Successfully written to D:/Downloads/GL010036/
# Frame No : 2880 Successfully written to D:/Downloads/GL010036/
# Frame No : 2910 Successfully written to D:/Downloads/GL010036/
# Frame No : 2940 Successfully written to D:/Downloads/GL010036/
# Frame No : 2970 Successfully written to D:/Downloads/GL010036/
# Frame No : 3000 Successfully written to D:/Downloads/GL010036/
# Frame No : 3030 Successfully written to D:/Downloads/GL010036/
# Frame No : 3060 Successfully written to D:/Downloads/GL010036/
# Frame No : 3090 Successfully written to D:/Downloads/GL010036/
# Frame No : 3120 Successfully written to D:/Downloads/GL010036/
# Frame No : 3150 Successfully written to D:/Downloads/GL010036/
# Frame No : 3180 Successfully written to D:/Downloads/GL010036/
# Frame No : 3210 Successfully written to D:/Downloads/GL010036/
# Frame No : 3240 Successfully written to D:/Downloads/GL010036/
# Frame No : 3270 Successfully written to D:/Downloads/GL010036/
# Frame No : 3300 Successfully written to D:/Downloads/GL010036/
# Frame No : 3330 Successfully written to D:/Downloads/GL010036/
# Frame No : 3360 Successfully written to D:/Downloads/GL010036/
# Frame No : 3390 Successfully written to D:/Downloads/GL010036/
# Frame No : 3420 Successfully written to D:/Downloads/GL010036/
# Frame No : 3450 Successfully written to D:/Downloads/GL010036/
# Frame No : 3480 Successfully written to D:/Downloads/GL010036/
# Frame No : 3510 Successfully written to D:/Downloads/GL010036/
# Frame No : 3540 Successfully written to D:/Downloads/GL010036/
# Frame No : 3570 Successfully written to D:/Downloads/GL010036/
# Frame No : 3600 Successfully written to D:/Downloads/GL010036/
# Frame No : 3630 Successfully written to D:/Downloads/GL010036/
# Frame No : 3660 Successfully written to D:/Downloads/GL010036/
# Frame No : 3690 Successfully written to D:/Downloads/GL010036/
# Frame No : 3720 Successfully written to D:/Downloads/GL010036/
# Frame No : 3750 Successfully written to D:/Downloads/GL010036/
# Frame No : 3780 Successfully written to D:/Downloads/GL010036/
# Frame No : 3810 Successfully written to D:/Downloads/GL010036/
# Frame No : 3840 Successfully written to D:/Downloads/GL010036/
# Frame No : 3870 Successfully written to D:/Downloads/GL010036/
# Frame No : 3900 Successfully written to D:/Downloads/GL010036/
# Frame No : 3930 Successfully written to D:/Downloads/GL010036/
# Frame No : 3960 Successfully written to D:/Downloads/GL010036/
# Frame No : 3990 Successfully written to D:/Downloads/GL010036/
# Frame No : 4020 Successfully written to D:/Downloads/GL010036/
# Frame No : 4050 Successfully written to D:/Downloads/GL010036/
# Frame No : 4080 Successfully written to D:/Downloads/GL010036/
# Frame No : 4110 Successfully written to D:/Downloads/GL010036/
# Frame No : 4140 Successfully written to D:/Downloads/GL010036/
# Frame No : 4170 Successfully written to D:/Downloads/GL010036/
# Frame No : 4200 Successfully written to D:/Downloads/GL010036/
# Frame No : 4230 Successfully written to D:/Downloads/GL010036/
# Frame No : 4260 Successfully written to D:/Downloads/GL010036/
# Frame No : 4290 Successfully written to D:/Downloads/GL010036/
# Frame No : 4320 Successfully written to D:/Downloads/GL010036/
# Frame No : 4350 Successfully written to D:/Downloads/GL010036/
# Frame No : 4380 Successfully written to D:/Downloads/GL010036/
# Frame No : 4410 Successfully written to D:/Downloads/GL010036/
# Frame No : 4440 Successfully written to D:/Downloads/GL010036/
# Frame No : 4470 Successfully written to D:/Downloads/GL010036/
# Frame No : 4500 Successfully written to D:/Downloads/GL010036/
# Frame No : 4530 Successfully written to D:/Downloads/GL010036/
# Frame No : 4560 Successfully written to D:/Downloads/GL010036/
# Frame No : 4590 Successfully written to D:/Downloads/GL010036/
# Frame No : 4620 Successfully written to D:/Downloads/GL010036/
# Frame No : 4650 Successfully written to D:/Downloads/GL010036/
# Frame No : 4680 Successfully written to D:/Downloads/GL010036/
# Frame No : 4710 Successfully written to D:/Downloads/GL010036/
# Frame No : 4740 Successfully written to D:/Downloads/GL010036/
# Frame No : 4770 Successfully written to D:/Downloads/GL010036/
# Frame No : 4800 Successfully written to D:/Downloads/GL010036/
# Frame No : 4830 Successfully written to D:/Downloads/GL010036/
# Frame No : 4860 Successfully written to D:/Downloads/GL010036/
# Frame No : 4890 Successfully written to D:/Downloads/GL010036/
# Frame No : 4920 Successfully written to D:/Downloads/GL010036/
# Frame No : 4950 Successfully written to D:/Downloads/GL010036/
# Frame No : 4980 Successfully written to D:/Downloads/GL010036/
# Frame No : 5010 Successfully written to D:/Downloads/GL010036/
# Frame No : 5040 Successfully written to D:/Downloads/GL010036/
# Frame No : 5070 Successfully written to D:/Downloads/GL010036/
# Frame No : 5100 Successfully written to D:/Downloads/GL010036/
# Frame No : 5130 Successfully written to D:/Downloads/GL010036/
# Frame No : 5160 Successfully written to D:/Downloads/GL010036/
# Frame No : 5190 Successfully written to D:/Downloads/GL010036/
# Frame No : 5220 Successfully written to D:/Downloads/GL010036/
# Frame No : 5250 Successfully written to D:/Downloads/GL010036/
# Frame No : 5280 Successfully written to D:/Downloads/GL010036/
# Frame No : 5310 Successfully written to D:/Downloads/GL010036/
# Frame No : 5340 Successfully written to D:/Downloads/GL010036/
# Frame No : 5370 Successfully written to D:/Downloads/GL010036/
# Frame No : 5400 Successfully written to D:/Downloads/GL010036/
# Frame No : 5430 Successfully written to D:/Downloads/GL010036/
# Frame No : 5460 Successfully written to D:/Downloads/GL010036/
# Frame No : 5490 Successfully written to D:/Downloads/GL010036/
# Frame No : 5520 Successfully written to D:/Downloads/GL010036/
# Frame No : 5550 Successfully written to D:/Downloads/GL010036/
# Frame No : 5580 Successfully written to D:/Downloads/GL010036/
# Frame No : 5610 Successfully written to D:/Downloads/GL010036/
# Frame No : 5640 Successfully written to D:/Downloads/GL010036/
# Frame No : 5670 Successfully written to D:/Downloads/GL010036/
# Frame No : 5700 Successfully written to D:/Downloads/GL010036/
# Frame No : 5730 Successfully written to D:/Downloads/GL010036/
# Frame No : 5760 Successfully written to D:/Downloads/GL010036/
# Frame No : 5790 Successfully written to D:/Downloads/GL010036/
# Frame No : 5820 Successfully written to D:/Downloads/GL010036/
# Frame No : 5850 Successfully written to D:/Downloads/GL010036/
# Frame No : 5880 Successfully written to D:/Downloads/GL010036/
# Frame No : 5910 Successfully written to D:/Downloads/GL010036/
# Frame No : 5940 Successfully written to D:/Downloads/GL010036/
# Frame No : 5970 Successfully written to D:/Downloads/GL010036/
# Frame No : 6000 Successfully written to D:/Downloads/GL010036/
# Frame No : 6030 Successfully written to D:/Downloads/GL010036/
# Frame No : 6060 Successfully written to D:/Downloads/GL010036/
# Frame No : 6090 Successfully written to D:/Downloads/GL010036/
# Frame No : 6120 Successfully written to D:/Downloads/GL010036/
# Frame No : 6150 Successfully written to D:/Downloads/GL010036/
# Frame No : 6180 Successfully written to D:/Downloads/GL010036/
# Frame No : 6210 Successfully written to D:/Downloads/GL010036/
# Frame No : 6240 Successfully written to D:/Downloads/GL010036/
# Frame No : 6270 Successfully written to D:/Downloads/GL010036/
# Frame No : 6300 Successfully written to D:/Downloads/GL010036/
# Frame No : 6330 Successfully written to D:/Downloads/GL010036/
# Frame No : 6360 Successfully written to D:/Downloads/GL010036/
# Frame No : 6390 Successfully written to D:/Downloads/GL010036/
# Frame No : 6420 Successfully written to D:/Downloads/GL010036/
# Frame No : 6450 Successfully written to D:/Downloads/GL010036/
# Frame No : 6480 Successfully written to D:/Downloads/GL010036/
# Frame No : 6510 Successfully written to D:/Downloads/GL010036/
# Frame No : 6540 Successfully written to D:/Downloads/GL010036/
# Frame No : 6570 Successfully written to D:/Downloads/GL010036/
# Frame No : 6600 Successfully written to D:/Downloads/GL010036/
# Frame No : 6630 Successfully written to D:/Downloads/GL010036/
# Frame No : 6660 Successfully written to D:/Downloads/GL010036/
# Frame No : 6690 Successfully written to D:/Downloads/GL010036/
# Frame No : 6720 Successfully written to D:/Downloads/GL010036/
# Frame No : 6750 Successfully written to D:/Downloads/GL010036/
# Frame No : 6780 Successfully written to D:/Downloads/GL010036/
# Frame No : 6810 Successfully written to D:/Downloads/GL010036/
# Frame No : 6840 Successfully written to D:/Downloads/GL010036/
# Frame No : 6870 Successfully written to D:/Downloads/GL010036/
# Frame No : 6900 Successfully written to D:/Downloads/GL010036/
# Frame No : 6930 Successfully written to D:/Downloads/GL010036/
# Frame No : 6960 Successfully written to D:/Downloads/GL010036/
# Frame No : 6990 Successfully written to D:/Downloads/GL010036/
# Frame No : 7020 Successfully written to D:/Downloads/GL010036/
# Frame No : 7050 Successfully written to D:/Downloads/GL010036/
# Frame No : 7080 Successfully written to D:/Downloads/GL010036/
# Frame No : 7110 Successfully written to D:/Downloads/GL010036/
# Frame No : 7140 Successfully written to D:/Downloads/GL010036/
# Frame No : 7170 Successfully written to D:/Downloads/GL010036/
# Frame No : 7200 Successfully written to D:/Downloads/GL010036/
# Frame No : 7230 Successfully written to D:/Downloads/GL010036/
# Frame No : 7260 Successfully written to D:/Downloads/GL010036/
# Frame No : 7290 Successfully written to D:/Downloads/GL010036/
# Frame No : 7320 Successfully written to D:/Downloads/GL010036/
# Frame No : 7350 Successfully written to D:/Downloads/GL010036/
# Frame No : 7380 Successfully written to D:/Downloads/GL010036/
# Frame No : 7410 Successfully written to D:/Downloads/GL010036/
# Frame No : 7440 Successfully written to D:/Downloads/GL010036/
# Frame No : 7470 Successfully written to D:/Downloads/GL010036/
# Frame No : 7500 Successfully written to D:/Downloads/GL010036/
# Frame No : 7530 Successfully written to D:/Downloads/GL010036/
# Frame No : 7560 Successfully written to D:/Downloads/GL010036/
# Frame No : 7590 Successfully written to D:/Downloads/GL010036/
# Frame No : 7620 Successfully written to D:/Downloads/GL010036/
# Frame No : 7650 Successfully written to D:/Downloads/GL010036/
# Frame No : 7680 Successfully written to D:/Downloads/GL010036/
# Frame No : 7710 Successfully written to D:/Downloads/GL010036/
# Frame No : 7740 Successfully written to D:/Downloads/GL010036/
# Frame No : 7770 Successfully written to D:/Downloads/GL010036/
# Frame No : 7800 Successfully written to D:/Downloads/GL010036/
# Frame No : 7830 Successfully written to D:/Downloads/GL010036/
# Frame No : 7860 Successfully written to D:/Downloads/GL010036/
# Frame No : 7890 Successfully written to D:/Downloads/GL010036/
# Frame No : 7920 Successfully written to D:/Downloads/GL010036/
# Frame No : 7950 Successfully written to D:/Downloads/GL010036/
# Frame No : 7980 Successfully written to D:/Downloads/GL010036/
# Frame No : 8010 Successfully written to D:/Downloads/GL010036/
# Frame No : 8040 Successfully written to D:/Downloads/GL010036/
# Frame No : 8070 Successfully written to D:/Downloads/GL010036/
# Frame No : 8100 Successfully written to D:/Downloads/GL010036/
# Frame No : 8130 Successfully written to D:/Downloads/GL010036/
# Frame No : 8160 Successfully written to D:/Downloads/GL010036/
# Frame No : 8190 Successfully written to D:/Downloads/GL010036/
# Frame No : 8220 Successfully written to D:/Downloads/GL010036/
# Frame No : 8250 Successfully written to D:/Downloads/GL010036/
# Frame No : 8280 Successfully written to D:/Downloads/GL010036/
# Frame No : 8310 Successfully written to D:/Downloads/GL010036/
# Frame No : 8340 Successfully written to D:/Downloads/GL010036/
# Frame No : 8370 Successfully written to D:/Downloads/GL010036/
# Frame No : 8400 Successfully written to D:/Downloads/GL010036/
# Frame No : 8430 Successfully written to D:/Downloads/GL010036/
# Frame No : 8460 Successfully written to D:/Downloads/GL010036/
# Frame No : 8490 Successfully written to D:/Downloads/GL010036/
# Frame No : 8520 Successfully written to D:/Downloads/GL010036/
# Frame No : 8550 Successfully written to D:/Downloads/GL010036/
# Frame No : 8580 Successfully written to D:/Downloads/GL010036/
# Frame No : 8610 Successfully written to D:/Downloads/GL010036/
# Frame No : 8640 Successfully written to D:/Downloads/GL010036/
# Frame No : 8670 Successfully written to D:/Downloads/GL010036/
# Frame No : 8700 Successfully written to D:/Downloads/GL010036/
# Frame No : 8730 Successfully written to D:/Downloads/GL010036/
# Frame No : 8760 Successfully written to D:/Downloads/GL010036/
# Frame No : 8790 Successfully written to D:/Downloads/GL010036/
# Frame No : 8820 Successfully written to D:/Downloads/GL010036/
# Frame No : 8850 Successfully written to D:/Downloads/GL010036/
# Frame No : 8880 Successfully written to D:/Downloads/GL010036/
# Frame No : 8910 Successfully written to D:/Downloads/GL010036/
# Frame No : 8940 Successfully written to D:/Downloads/GL010036/
# Frame No : 8970 Successfully written to D:/Downloads/GL010036/
# Frame No : 9000 Successfully written to D:/Downloads/GL010036/
# Frame No : 9030 Successfully written to D:/Downloads/GL010036/
# Frame No : 9060 Successfully written to D:/Downloads/GL010036/
# Frame No : 9090 Successfully written to D:/Downloads/GL010036/
# Frame No : 9120 Successfully written to D:/Downloads/GL010036/
# Frame No : 9150 Successfully written to D:/Downloads/GL010036/
# Frame No : 9180 Successfully written to D:/Downloads/GL010036/
# Frame No : 9210 Successfully written to D:/Downloads/GL010036/
# Frame No : 9240 Successfully written to D:/Downloads/GL010036/

# %% [markdown]
# ## Fetching images of individual cam

# %%
sizeR = size(os.listdir(pathR))
# sizeL = size(os.listdir(pathL))

offset = 300
listingsR = []
for i in range(offset+30,offset+30*sizeR-30,30 ):
    listingsR.append(f'{i}.png')
#endfor

# listingsL = []
# for i in range(offset+0, offset+sizeL):
#     listingsL.append(f'{i}_L_.png')
# #endfor

print(sizeR)
print(listingsR)

print("\nAfter shuffle:\n")
random.shuffle(listingsR)
# random.shuffle(listingsL)
print(listingsR)
# Out:
# 151
# ['330.png', '360.png', '390.png', '420.png', '450.png', '480.png', '510.png', '540.png', '570.png', '600.png', '630.png', '660.png', '690.png', '720.png', '750.png', '780.png', '810.png', '840.png', '870.png', '900.png', '930.png', '960.png', '990.png', '1020.png', '1050.png', '1080.png', '1110.png', '1140.png', '1170.png', '1200.png', '1230.png', '1260.png', '1290.png', '1320.png', '1350.png', '1380.png', '1410.png', '1440.png', '1470.png', '1500.png', '1530.png', '1560.png', '1590.png', '1620.png', '1650.png', '1680.png', '1710.png', '1740.png', '1770.png', '1800.png', '1830.png', '1860.png', '1890.png', '1920.png', '1950.png', '1980.png', '2010.png', '2040.png', '2070.png', '2100.png', '2130.png', '2160.png', '2190.png', '2220.png', '2250.png', '2280.png', '2310.png', '2340.png', '2370.png', '2400.png', '2430.png', '2460.png', '2490.png', '2520.png', '2550.png', '2580.png', '2610.png', '2640.png', '2670.png', '2700.png', '2730.png', '2760.png', '2790.png', '2820.png', '2850.png', '2880.png', '2910.png', '2940.png', '2970.png', '3000.png', '3030.png', '3060.png', '3090.png', '3120.png', '3150.png', '3180.png', '3210.png', '3240.png', '3270.png', '3300.png', '3330.png', '3360.png', '3390.png', '3420.png', '3450.png', '3480.png', '3510.png', '3540.png', '3570.png', '3600.png', '3630.png', '3660.png', '3690.png', '3720.png', '3750.png', '3780.png', '3810.png', '3840.png', '3870.png', '3900.png', '3930.png', '3960.png', '3990.png', '4020.png', '4050.png', '4080.png', '4110.png', '4140.png', '4170.png', '4200.png', '4230.png', '4260.png', '4290.png', '4320.png', '4350.png', '4380.png', '4410.png', '4440.png', '4470.png', '4500.png', '4530.png', '4560.png', '4590.png', '4620.png', '4650.png', '4680.png', '4710.png', '4740.png', '4770.png']
#
# After shuffle:
#
# ['630.png', '1710.png', '4110.png', '3990.png', '1680.png', '4530.png', '960.png', '1470.png', '1290.png', '3870.png', '3510.png', '3480.png', '2010.png', '2070.png', '2610.png', '2730.png', '2790.png', '3060.png', '2640.png', '2190.png', '2400.png', '2850.png', '420.png', '4380.png', '3810.png', '1170.png', '1050.png', '2250.png', '1260.png', '1770.png', '3150.png', '2370.png', '4050.png', '4230.png', '750.png', '810.png', '540.png', '3600.png', '1500.png', '3180.png', '4170.png', '1650.png', '2670.png', '4770.png', '2220.png', '2820.png', '1830.png', '870.png', '1980.png', '2490.png', '2460.png', '4140.png', '2550.png', '990.png', '390.png', '3540.png', '3270.png', '3000.png', '2340.png', '2100.png', '4350.png', '1890.png', '4470.png', '3570.png', '3840.png', '4590.png', '4680.png', '450.png', '3300.png', '4200.png', '4500.png', '3210.png', '3780.png', '3660.png', '330.png', '4410.png', '1320.png', '1380.png', '1530.png', '3330.png', '3030.png', '1020.png', '1350.png', '2310.png', '2430.png', '4440.png', '1200.png', '1410.png', '1140.png', '900.png', '2700.png', '3750.png', '2910.png', '3690.png', '1110.png', '600.png', '3390.png', '3090.png', '2580.png', '1740.png', '3120.png', '2280.png', '4080.png', '360.png', '480.png', '2520.png', '3720.png', '840.png', '1620.png', '3960.png', '1860.png', '1440.png', '2940.png', '2130.png', '4320.png', '3900.png', '570.png', '780.png', '1080.png', '1950.png', '3240.png', '2760.png', '2970.png', '4290.png', '720.png', '2880.png', '4740.png', '930.png', '3930.png', '2040.png', '4650.png', '4710.png', '4620.png', '690.png', '1230.png', '4260.png', '3450.png', '1920.png', '3360.png', '660.png', '4020.png', '1800.png', '510.png', '4560.png', '3420.png', '2160.png', '1560.png', '1590.png', '3630.png']

# %%
imgRList = []
i = 0
while(i<sizeR-2):
    imR = cv2.imread(pathR+listingsR[i])
    imgRList.append(imR)
    i+=1
#endwhile
print(len(imgRList))

# imgLList = []
# i = 0
# while(i<sizeL):
#     imL = cv2.imread(pathL+listingsL[i])
#     imgLList.append(imL)
#     i+=1
# #endwhile
# print(len(imgLList))

if len(imgRList) > 0:
    print(imgRList[0].shape)
#endif

# if len(imgLList) > 0:
#     print(imgLList[0].shape)
# #endif
# Out:
# 149
# (1080, 1920, 3)

# %%
chessSqSize = 27.3
h, w = 7, 5
patternSize = (h,w)
# prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
objp = np.zeros((w*h,3), np.float32)
objp[:,:2] = np.mgrid[0:h,0:w].T.reshape(-1,2)*chessSqSize
print(objp)

chessCriteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 26, 0.001)
findChessboardFlags = None
downScaleSize = (640,480)
# font
font = cv2.FONT_HERSHEY_SIMPLEX
# org
org = (50, 50)
# fontScale
fontScale = 1
# Blue color in BGR
color = (255, 100, 50)
# Line thickness of 2 px
thickness = 2
# Out:
# [[  0.    0.    0. ]
#  [ 27.3   0.    0. ]
#  [ 54.6   0.    0. ]
#  [ 81.9   0.    0. ]
#  [109.2   0.    0. ]
#  [136.5   0.    0. ]
#  [163.8   0.    0. ]
#  [  0.   27.3   0. ]
#  [ 27.3  27.3   0. ]
#  [ 54.6  27.3   0. ]
#  [ 81.9  27.3   0. ]
#  [109.2  27.3   0. ]
#  [136.5  27.3   0. ]
#  [163.8  27.3   0. ]
#  [  0.   54.6   0. ]
#  [ 27.3  54.6   0. ]
#  [ 54.6  54.6   0. ]
#  [ 81.9  54.6   0. ]
#  [109.2  54.6   0. ]
#  [136.5  54.6   0. ]
#  [163.8  54.6   0. ]
#  [  0.   81.9   0. ]
#  [ 27.3  81.9   0. ]
#  [ 54.6  81.9   0. ]
#  [ 81.9  81.9   0. ]
#  [109.2  81.9   0. ]
#  [136.5  81.9   0. ]
#  [163.8  81.9   0. ]
#  [  0.  109.2   0. ]
#  [ 27.3 109.2   0. ]
#  [ 54.6 109.2   0. ]
#  [ 81.9 109.2   0. ]
#  [109.2 109.2   0. ]
#  [136.5 109.2   0. ]
#  [163.8 109.2   0. ]]

# %% [markdown]
# ## Right cam calibration

# %%
imgRightPoints = []
objRightPoints = []
rightImage = None
rightImageGray = None
j=0
while(j<sizeR-2):
    print(f'getting: {j}...')
    imageSize = imgRList[j].shape
    rightImageGray = cv2.cvtColor(imgRList[j], cv2.COLOR_BGR2GRAY)
    rightImage = imgRList[j].copy()
    rightFound, rightCorners = cv2.findChessboardCorners(rightImageGray, patternSize, flags = findChessboardFlags)
    
    if rightFound:
        cv2.cornerSubPix(rightImageGray, rightCorners, (11,11), (-1,-1), chessCriteria)
        print(f'{str(rightFound)}: {j}')
    #endif

    cv2.drawChessboardCorners(rightImage, patternSize, rightCorners, rightFound)
    cv2.putText(rightImage, f'{j}/{sizeR}', org, font, fontScale, color, thickness, cv2.LINE_AA)

    if rightFound:
        cv2.putText(rightImage, 'Press a to accept, any other key to reject.', (50, 150), font, fontScale, color, thickness, cv2.LINE_AA)
        cv2.imshow(f'r chess', cv2.resize(rightImage, downScaleSize))
        if cv2.waitKey(0) & 0xff == ord('a'):
            imgRightPoints.append(rightCorners)
            objRightPoints.append(objp)
            print(f'accepted: {j}')
        else:
            cv2.waitKey(200)
            print(f'rejected: {j}')
        #endif
    else:
        cv2.imshow(f'r chess', cv2.resize(rightImage, downScaleSize))
        cv2.waitKey(200)
        print(f'auto rejected: {j}')
    #endif

    print('...........................')

    j+=1
#endwhile
cv2.destroyAllWindows()
# Out:
# getting: 0...
# auto rejected: 0
# ...........................
# getting: 1...
# True: 1
# accepted: 1
# ...........................
# getting: 2...
# auto rejected: 2
# ...........................
# getting: 3...
# auto rejected: 3
# ...........................
# getting: 4...
# True: 4
# accepted: 4
# ...........................
# getting: 5...
# auto rejected: 5
# ...........................
# getting: 6...
# True: 6
# accepted: 6
# ...........................
# getting: 7...
# auto rejected: 7
# ...........................
# getting: 8...
# True: 8
# accepted: 8
# ...........................
# getting: 9...
# True: 9
# accepted: 9
# ...........................
# getting: 10...
# True: 10
# accepted: 10
# ...........................
# getting: 11...
# auto rejected: 11
# ...........................
# getting: 12...
# True: 12
# accepted: 12
# ...........................
# getting: 13...
# True: 13
# accepted: 13
# ...........................
# getting: 14...
# auto rejected: 14
# ...........................
# getting: 15...
# auto rejected: 15
# ...........................
# getting: 16...
# auto rejected: 16
# ...........................
# getting: 17...
# True: 17
# accepted: 17
# ...........................
# getting: 18...
# auto rejected: 18
# ...........................
# getting: 19...
# True: 19
# accepted: 19
# ...........................
# getting: 20...
# True: 20
# accepted: 20
# ...........................
# getting: 21...
# True: 21
# accepted: 21
# ...........................
# getting: 22...
# auto rejected: 22
# ...........................
# getting: 23...
# auto rejected: 23
# ...........................
# getting: 24...
# True: 24
# accepted: 24
# ...........................
# getting: 25...
# True: 25
# accepted: 25
# ...........................
# getting: 26...
# True: 26
# accepted: 26
# ...........................
# getting: 27...
# True: 27
# accepted: 27
# ...........................
# getting: 28...
# True: 28
# accepted: 28
# ...........................
# getting: 29...
# True: 29
# accepted: 29
# ...........................
# getting: 30...
# True: 30
# accepted: 30
# ...........................
# getting: 31...
# True: 31
# accepted: 31
# ...........................
# getting: 32...
# auto rejected: 32
# ...........................
# getting: 33...
# auto rejected: 33
# ...........................
# getting: 34...
# auto rejected: 34
# ...........................
# getting: 35...
# auto rejected: 35
# ...........................
# getting: 36...
# auto rejected: 36
# ...........................
# getting: 37...
# True: 37
# accepted: 37
# ...........................
# getting: 38...
# auto rejected: 38
# ...........................
# getting: 39...
# True: 39
# accepted: 39
# ...........................
# getting: 40...
# auto rejected: 40
# ...........................
# getting: 41...
# True: 41
# accepted: 41
# ...........................
# getting: 42...
# auto rejected: 42
# ...........................
# getting: 43...
# auto rejected: 43
# ...........................
# getting: 44...
# True: 44
# accepted: 44
# ...........................
# getting: 45...
# auto rejected: 45
# ...........................
# getting: 46...
# True: 46
# accepted: 46
# ...........................
# getting: 47...
# auto rejected: 47
# ...........................
# getting: 48...
# True: 48
# accepted: 48
# ...........................
# getting: 49...
# True: 49
# accepted: 49
# ...........................
# getting: 50...
# True: 50
# accepted: 50
# ...........................
# getting: 51...
# auto rejected: 51
# ...........................
# getting: 52...
# True: 52
# accepted: 52
# ...........................
# getting: 53...
# True: 53
# accepted: 53
# ...........................
# getting: 54...
# auto rejected: 54
# ...........................
# getting: 55...
# True: 55
# accepted: 55
# ...........................
# getting: 56...
# True: 56
# accepted: 56
# ...........................
# getting: 57...
# True: 57
# accepted: 57
# ...........................
# getting: 58...
# True: 58
# accepted: 58
# ...........................
# getting: 59...
# True: 59
# accepted: 59
# ...........................
# getting: 60...
# auto rejected: 60
# ...........................
# getting: 61...
# True: 61
# accepted: 61
# ...........................
# getting: 62...
# auto rejected: 62
# ...........................
# getting: 63...
# True: 63
# accepted: 63
# ...........................
# getting: 64...
# True: 64
# accepted: 64
# ...........................
# getting: 65...
# auto rejected: 65
# ...........................
# getting: 66...
# auto rejected: 66
# ...........................
# getting: 67...
# auto rejected: 67
# ...........................
# getting: 68...
# True: 68
# accepted: 68
# ...........................
# getting: 69...
# auto rejected: 69
# ...........................
# getting: 70...
# auto rejected: 70
# ...........................
# getting: 71...
# True: 71
# accepted: 71
# ...........................
# getting: 72...
# True: 72
# accepted: 72
# ...........................
# getting: 73...
# True: 73
# accepted: 73
# ...........................
# getting: 74...
# True: 74
# accepted: 74
# ...........................
# getting: 75...
# auto rejected: 75
# ...........................
# getting: 76...
# auto rejected: 76
# ...........................
# getting: 77...
# auto rejected: 77
# ...........................
# getting: 78...
# auto rejected: 78
# ...........................
# getting: 79...
# True: 79
# accepted: 79
# ...........................
# getting: 80...
# True: 80
# accepted: 80
# ...........................
# getting: 81...
# True: 81
# accepted: 81
# ...........................
# getting: 82...
# auto rejected: 82
# ...........................
# getting: 83...
# True: 83
# accepted: 83
# ...........................
# getting: 84...
# True: 84
# accepted: 84
# ...........................
# getting: 85...
# auto rejected: 85
# ...........................
# getting: 86...
# True: 86
# accepted: 86
# ...........................
# getting: 87...
# auto rejected: 87
# ...........................
# getting: 88...
# True: 88
# accepted: 88
# ...........................
# getting: 89...
# auto rejected: 89
# ...........................
# getting: 90...
# auto rejected: 90
# ...........................
# getting: 91...
# True: 91
# accepted: 91
# ...........................
# getting: 92...
# True: 92
# accepted: 92
# ...........................
# getting: 93...
# True: 93
# accepted: 93
# ...........................
# getting: 94...
# True: 94
# accepted: 94
# ...........................
# getting: 95...
# auto rejected: 95
# ...........................
# getting: 96...
# True: 96
# accepted: 96
# ...........................
# getting: 97...
# True: 97
# accepted: 97
# ...........................
# getting: 98...
# True: 98
# accepted: 98
# ...........................
# getting: 99...
# True: 99
# accepted: 99
# ...........................
# getting: 100...
# True: 100
# accepted: 100
# ...........................
# getting: 101...
# True: 101
# accepted: 101
# ...........................
# getting: 102...
# auto rejected: 102
# ...........................
# getting: 103...
# auto rejected: 103
# ...........................
# getting: 104...
# auto rejected: 104
# ...........................
# getting: 105...
# True: 105
# accepted: 105
# ...........................
# getting: 106...
# True: 106
# accepted: 106
# ...........................
# getting: 107...
# auto rejected: 107
# ...........................
# getting: 108...
# True: 108
# accepted: 108
# ...........................
# getting: 109...
# True: 109
# accepted: 109
# ...........................
# getting: 110...
# True: 110
# accepted: 110
# ...........................
# getting: 111...
# auto rejected: 111
# ...........................
# getting: 112...
# True: 112
# accepted: 112
# ...........................
# getting: 113...
# True: 113
# accepted: 113
# ...........................
# getting: 114...
# auto rejected: 114
# ...........................
# getting: 115...
# True: 115
# accepted: 115
# ...........................
# getting: 116...
# auto rejected: 116
# ...........................
# getting: 117...
# auto rejected: 117
# ...........................
# getting: 118...
# True: 118
# accepted: 118
# ...........................
# getting: 119...
# True: 119
# accepted: 119
# ...........................
# getting: 120...
# True: 120
# accepted: 120
# ...........................
# getting: 121...
# auto rejected: 121
# ...........................
# getting: 122...
# True: 122
# accepted: 122
# ...........................
# getting: 123...
# auto rejected: 123
# ...........................
# getting: 124...
# auto rejected: 124
# ...........................
# getting: 125...
# True: 125
# accepted: 125
# ...........................
# getting: 126...
# auto rejected: 126
# ...........................
# getting: 127...
# auto rejected: 127
# ...........................
# getting: 128...
# True: 128
# accepted: 128
# ...........................
# getting: 129...
# True: 129
# accepted: 129
# ...........................
# getting: 130...
# auto rejected: 130
# ...........................
# getting: 131...
# auto rejected: 131
# ...........................
# getting: 132...
# auto rejected: 132
# ...........................
# getting: 133...
# auto rejected: 133
# ...........................
# getting: 134...
# True: 134
# accepted: 134
# ...........................
# getting: 135...
# auto rejected: 135
# ...........................
# getting: 136...
# auto rejected: 136
# ...........................
# getting: 137...
# True: 137
# accepted: 137
# ...........................
# getting: 138...
# True: 138
# accepted: 138
# ...........................
# getting: 139...
# auto rejected: 139
# ...........................
# getting: 140...
# auto rejected: 140
# ...........................
# getting: 141...
# True: 141
# accepted: 141
# ...........................
# getting: 142...
# auto rejected: 142
# ...........................
# getting: 143...
# auto rejected: 143
# ...........................
# getting: 144...
# auto rejected: 144
# ...........................
# getting: 145...
# True: 145
# accepted: 145
# ...........................
# getting: 146...
# auto rejected: 146
# ...........................
# getting: 147...
# auto rejected: 147
# ...........................
# getting: 148...
# True: 148
# accepted: 148
# ...........................

# %%
cv2.destroyAllWindows()
print(len(imgRightPoints))
# print(len(objRightPoints))
# Out:
# 81

# %%
# objRightPoints[0].type()
retR, mtxR, distR, rvecsR, tvecsR = cv2.calibrateCamera(
    objRightPoints,
    imgRightPoints,
    rightImageGray.shape[::-1],
    None,None
)

hR,wR = rightImageGray.shape[:2]
OmtxR, roiR = cv2.getOptimalNewCameraMatrix(mtxR, distR, (wR,hR), 1, (wR,hR))
print('ret - right: ', retR)
print("roiR: ", roiR)

# https://docs.opencv.org/4.5.4/dc/dbb/tutorial_py_calibration.html
meanRightError = 0
for i in range(len(objRightPoints)):
    imgRightPoints2, _ = cv2.projectPoints(objRightPoints[i], rvecsR[i], tvecsR[i], mtxR, distR)
    error = cv2.norm(imgRightPoints[i], imgRightPoints2, cv2.NORM_L2)/len(imgRightPoints2)
    meanRightError += error
#endfor

print("Total reprojection error: {}".format(meanRightError/len(objRightPoints)))
# Out:
# ret - right:  0.2672547491489908
# roiR:  (10, 22, 1896, 1036)
# Total reprojection error: 0.043415211247885534

# %%
img = cv2.cvtColor(imgRList[20], cv2.COLOR_BGR2GRAY)
# using cv2.undistort
dst = cv2.undistort(img, mtxR, distR, None, OmtxR)
x,y,w,h = roiR
dst = dst[y:y+h, x:x+w]

# using remapping
rightMap = cv2.initUndistortRectifyMap(mtxR, distR, None, OmtxR, img.shape[::-1], cv2.CV_16SC2)
rdst = cv2.remap(img,rightMap[0],rightMap[1], cv2.INTER_LANCZOS4, cv2.BORDER_CONSTANT, 0)
x,y,w,h = roiR
rdst = rdst[y:y+h, x:x+w]

cv2.imshow('undist', cv2.resize(dst, downScaleSize))
cv2.imshow('rundist', cv2.resize(rdst, downScaleSize))
cv2.imshow('img', cv2.resize(img, downScaleSize))
cv2.imwrite('img.png', cv2.resize(img, downScaleSize))
cv2.imwrite('rundist.png', cv2.resize(rdst, downScaleSize))
cv2.imwrite('undist.png', cv2.resize(dst, downScaleSize))

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.destroyAllWindows()

# %% [markdown]
# ## Left cam calibration

# %%
imgLeftPoints = []
objLeftPoints = []
leftImage = None
leftImageGray = None

j=0
while(j<sizeL):
    print(f'getting: {j}...')
    imageSize = imgLList[j].shape
    leftImageGray = cv2.cvtColor(imgLList[j], cv2.COLOR_BGR2GRAY)
    leftImage = imgLList[j].copy()
    leftFound, leftCorners = cv2.findChessboardCorners(leftImageGray, patternSize, flags = findChessboardFlags)
    
    if leftFound:
        cv2.cornerSubPix(leftImageGray, leftCorners, (11,11), (-1,-1), chessCriteria)
        print(f'{str(leftFound)}: {j}')
    #endif

    cv2.drawChessboardCorners(leftImage, patternSize, leftCorners, leftFound)
    cv2.putText(leftImage, f'{j}/{sizeL}', org, font, fontScale, color, thickness, cv2.LINE_AA)

    if leftFound:
        cv2.putText(leftImage, 'Press a to accept, any other key to reject.', (50, 150), font, fontScale, color, thickness, cv2.LINE_AA)
        cv2.imshow(f'l chess', cv2.resize(leftImage, downScaleSize))
        if cv2.waitKey(0) & 0xff == ord('a'):
            imgLeftPoints.append(leftCorners)
            objLeftPoints.append(objp)
            print(f'accepted: {j}')
        else:
            cv2.waitKey(200)
            print(f'rejected: {j}')
        #endif
    else:
        cv2.imshow(f'l chess', cv2.resize(leftImage, downScaleSize))
        cv2.waitKey(200)
        print(f'auto rejected: {j}')
    #endif

    print('...........................')

    j+=1
#endwhile
cv2.destroyAllWindows()
# Out:
# getting: 0...
# True: 0
# accepted: 0
# ...........................
# getting: 1...
# True: 1
# accepted: 1
# ...........................
# getting: 2...
# True: 2
# accepted: 2
# ...........................
# getting: 3...
# True: 3
# rejected: 3
# ...........................
# getting: 4...
# True: 4
# accepted: 4
# ...........................
# getting: 5...
# True: 5
# accepted: 5
# ...........................
# getting: 6...
# True: 6
# accepted: 6
# ...........................
# getting: 7...
# True: 7
# rejected: 7
# ...........................
# getting: 8...
# True: 8
# accepted: 8
# ...........................
# getting: 9...
# True: 9
# accepted: 9
# ...........................
# getting: 10...
# True: 10
# accepted: 10
# ...........................
# getting: 11...
# True: 11
# rejected: 11
# ...........................
# getting: 12...
# True: 12
# accepted: 12
# ...........................
# getting: 13...
# True: 13
# accepted: 13
# ...........................
# getting: 14...
# True: 14
# accepted: 14
# ...........................
# getting: 15...
# True: 15
# accepted: 15
# ...........................
# getting: 16...
# True: 16
# accepted: 16
# ...........................
# getting: 17...
# True: 17
# rejected: 17
# ...........................
# getting: 18...
# True: 18
# accepted: 18
# ...........................
# getting: 19...
# True: 19
# accepted: 19
# ...........................
# getting: 20...
# True: 20
# accepted: 20
# ...........................
# getting: 21...
# True: 21
# accepted: 21
# ...........................
# getting: 22...
# auto rejected: 22
# ...........................
# getting: 23...
# True: 23
# accepted: 23
# ...........................
# getting: 24...
# True: 24
# accepted: 24
# ...........................
# getting: 25...
# True: 25
# accepted: 25
# ...........................
# getting: 26...
# True: 26
# accepted: 26
# ...........................
# getting: 27...
# True: 27
# accepted: 27
# ...........................
# getting: 28...
# True: 28
# accepted: 28
# ...........................
# getting: 29...
# True: 29
# accepted: 29
# ...........................
# getting: 30...
# auto rejected: 30
# ...........................
# getting: 31...
# True: 31
# rejected: 31
# ...........................
# getting: 32...
# True: 32
# accepted: 32
# ...........................
# getting: 33...
# True: 33
# accepted: 33
# ...........................
# getting: 34...
# True: 34
# accepted: 34
# ...........................
# getting: 35...
# auto rejected: 35
# ...........................
# getting: 36...
# True: 36
# accepted: 36
# ...........................
# getting: 37...
# True: 37
# accepted: 37
# ...........................
# getting: 38...
# True: 38
# accepted: 38
# ...........................
# getting: 39...
# True: 39
# accepted: 39
# ...........................
# getting: 40...
# True: 40
# accepted: 40
# ...........................
# getting: 41...
# True: 41
# accepted: 41
# ...........................
# getting: 42...
# True: 42
# accepted: 42
# ...........................
# getting: 43...
# True: 43
# accepted: 43
# ...........................
# getting: 44...
# True: 44
# accepted: 44
# ...........................
# getting: 45...
# True: 45
# accepted: 45
# ...........................
# getting: 46...
# auto rejected: 46
# ...........................
# getting: 47...
# True: 47
# rejected: 47
# ...........................
# getting: 48...
# True: 48
# accepted: 48
# ...........................
# getting: 49...
# True: 49
# accepted: 49
# ...........................
# getting: 50...
# True: 50
# accepted: 50
# ...........................
# getting: 51...
# True: 51
# accepted: 51
# ...........................
# getting: 52...
# True: 52
# accepted: 52
# ...........................
# getting: 53...
# True: 53
# accepted: 53
# ...........................
# getting: 54...
# True: 54
# rejected: 54
# ...........................
# getting: 55...
# True: 55
# rejected: 55
# ...........................
# getting: 56...
# auto rejected: 56
# ...........................
# getting: 57...
# True: 57
# accepted: 57
# ...........................
# getting: 58...
# True: 58
# accepted: 58
# ...........................
# getting: 59...
# True: 59
# accepted: 59
# ...........................
# getting: 60...
# True: 60
# accepted: 60
# ...........................
# getting: 61...
# True: 61
# accepted: 61
# ...........................
# getting: 62...
# True: 62
# accepted: 62
# ...........................
# getting: 63...
# True: 63
# accepted: 63
# ...........................
# getting: 64...
# True: 64
# accepted: 64
# ...........................
# getting: 65...
# True: 65
# accepted: 65
# ...........................
# getting: 66...
# True: 66
# rejected: 66
# ...........................
# getting: 67...
# True: 67
# accepted: 67
# ...........................
# getting: 68...
# True: 68
# accepted: 68
# ...........................
# getting: 69...
# True: 69
# accepted: 69
# ...........................
# getting: 70...
# True: 70
# accepted: 70
# ...........................
# getting: 71...
# True: 71
# accepted: 71
# ...........................
# getting: 72...
# True: 72
# accepted: 72
# ...........................
# getting: 73...
# True: 73
# accepted: 73
# ...........................
# getting: 74...
# True: 74
# accepted: 74
# ...........................
# getting: 75...
# True: 75
# accepted: 75
# ...........................
# getting: 76...
# auto rejected: 76
# ...........................
# getting: 77...
# True: 77
# accepted: 77
# ...........................
# getting: 78...
# True: 78
# accepted: 78
# ...........................
# getting: 79...
# True: 79
# accepted: 79
# ...........................

# %%
cv2.destroyAllWindows()
print(len(imgLeftPoints))
print(len(objLeftPoints))
# Out:
# 65
# 65

# %%
retL, mtxL, distL, rvecsL, tvecsL = cv2.calibrateCamera(
    objLeftPoints,
    imgLeftPoints,
    leftImageGray.shape[::-1],
    None,None
)

hL,wL = leftImageGray.shape[:2]
OmtxL, roiL = cv2.getOptimalNewCameraMatrix(mtxL, distL, (wL,hL), 1, (wL,hL))
print('ret - left: ', retL)
print("roiL: ", roiL)

meanLeftError = 0
for i in range(len(objLeftPoints)):
    imgLeftPoints2, _ = cv2.projectPoints(objLeftPoints[i], rvecsL[i], tvecsL[i], mtxL, distL)
    error = cv2.norm(imgLeftPoints[i], imgLeftPoints2, cv2.NORM_L2)/len(imgLeftPoints2)
    meanLeftError += error
print("Total reprojection error: {}".format(meanLeftError/len(objLeftPoints)) )
# Out:
# ret - left:  0.9325628818591054
# roiL:  (164, 509, 555, 466)
# Total reprojection error: 0.07002697104714883

# %%
img = cv2.cvtColor(imgLList[75], cv2.COLOR_BGR2GRAY)
# using cv2.undistort
dst = cv2.undistort(img, mtxL, distL, None, OmtxL)
x,y,w,h = roiL
dst = dst[y:y+h, x:x+w]

# using remapping
leftMap = cv2.initUndistortRectifyMap(mtxL, distL, None, OmtxL, img.shape[::-1], cv2.CV_16SC2)
ldst = cv2.remap(img,leftMap[0],leftMap[1], cv2.INTER_LANCZOS4, cv2.BORDER_CONSTANT, 0)
x,y,w,h = roiL
ldst = ldst[y:y+h, x:x+w]

cv2.imshow('undist', cv2.resize(dst, downScaleSize))
cv2.imshow('rundist', cv2.resize(ldst, downScaleSize))
cv2.imshow('img', cv2.resize(img, downScaleSize))
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
formatm = [["fx","0","cx"],["0","fy","cy"],["0","0","1"]]
print('\n format -> \n',formatm)
print('\n mtxR -> \n',mtxR,2*'\n','OmtxR -> \n',OmtxR,2*'\n','mtxL -> \n',mtxL,2*'\n','OmtxL -> \n',OmtxL)
# Out:
#  format ->
#  [['fx', '0', 'cx'], ['0', 'fy', 'cy'], ['0', '0', '1']]
#
#  mtxR ->
#  [[865.01234245   0.         787.26088878]
#  [  0.         865.54856289 601.19468339]
#  [  0.           0.           1.        ]]
#
#  OmtxR ->
#  [[531.49023438   0.         768.26895233]
#  [  0.         598.56591797 607.48032173]
#  [  0.           0.           1.        ]]
#
#  mtxL ->
#  [[854.04143235   0.         814.66070348]
#  [  0.         853.99709956 589.73557822]
#  [  0.           0.           1.        ]]
#
#  OmtxL ->
#  [[296.04003906   0.         446.81178212]
#  [  0.         331.5017395  737.57300239]
#  [  0.           0.           1.        ]]

# %% [markdown]
# ## Stereo cam calibration

# %%
sizeStR = size(os.listdir(pathStR))
sizeStL = size(os.listdir(pathStL))

offset = 0
listingsStR = []
for i in range(offset+0, offset+sizeStR):
    listingsStR.append(f'{i}_R_.png')
#endfor

listingsStL = []
for i in range(offset+0, offset+sizeStL):
    listingsStL.append(f'{i}_L_.png')
#endfor

print(sizeStR, sizeStL)
print(listingsStR, listingsStL)

print("\nAfter shuffle:\n")
temp = list(zip(listingsStR, listingsStL))
random.shuffle(temp)
listingsStR, listingsStL = zip(*temp)
print(listingsStR, listingsStL)
# Out:
# 42 42
# ['0_R_.png', '1_R_.png', '2_R_.png', '3_R_.png', '4_R_.png', '5_R_.png', '6_R_.png', '7_R_.png', '8_R_.png', '9_R_.png', '10_R_.png', '11_R_.png', '12_R_.png', '13_R_.png', '14_R_.png', '15_R_.png', '16_R_.png', '17_R_.png', '18_R_.png', '19_R_.png', '20_R_.png', '21_R_.png', '22_R_.png', '23_R_.png', '24_R_.png', '25_R_.png', '26_R_.png', '27_R_.png', '28_R_.png', '29_R_.png', '30_R_.png', '31_R_.png', '32_R_.png', '33_R_.png', '34_R_.png', '35_R_.png', '36_R_.png', '37_R_.png', '38_R_.png', '39_R_.png', '40_R_.png', '41_R_.png'] ['0_L_.png', '1_L_.png', '2_L_.png', '3_L_.png', '4_L_.png', '5_L_.png', '6_L_.png', '7_L_.png', '8_L_.png', '9_L_.png', '10_L_.png', '11_L_.png', '12_L_.png', '13_L_.png', '14_L_.png', '15_L_.png', '16_L_.png', '17_L_.png', '18_L_.png', '19_L_.png', '20_L_.png', '21_L_.png', '22_L_.png', '23_L_.png', '24_L_.png', '25_L_.png', '26_L_.png', '27_L_.png', '28_L_.png', '29_L_.png', '30_L_.png', '31_L_.png', '32_L_.png', '33_L_.png', '34_L_.png', '35_L_.png', '36_L_.png', '37_L_.png', '38_L_.png', '39_L_.png', '40_L_.png', '41_L_.png']
#
# After shuffle:
#
# ('5_R_.png', '24_R_.png', '4_R_.png', '39_R_.png', '35_R_.png', '0_R_.png', '25_R_.png', '16_R_.png', '28_R_.png', '3_R_.png', '32_R_.png', '38_R_.png', '2_R_.png', '40_R_.png', '30_R_.png', '19_R_.png', '13_R_.png', '10_R_.png', '22_R_.png', '29_R_.png', '18_R_.png', '6_R_.png', '36_R_.png', '34_R_.png', '33_R_.png', '27_R_.png', '17_R_.png', '37_R_.png', '12_R_.png', '21_R_.png', '15_R_.png', '8_R_.png', '14_R_.png', '26_R_.png', '1_R_.png', '31_R_.png', '9_R_.png', '23_R_.png', '7_R_.png', '41_R_.png', '11_R_.png', '20_R_.png') ('5_L_.png', '24_L_.png', '4_L_.png', '39_L_.png', '35_L_.png', '0_L_.png', '25_L_.png', '16_L_.png', '28_L_.png', '3_L_.png', '32_L_.png', '38_L_.png', '2_L_.png', '40_L_.png', '30_L_.png', '19_L_.png', '13_L_.png', '10_L_.png', '22_L_.png', '29_L_.png', '18_L_.png', '6_L_.png', '36_L_.png', '34_L_.png', '33_L_.png', '27_L_.png', '17_L_.png', '37_L_.png', '12_L_.png', '21_L_.png', '15_L_.png', '8_L_.png', '14_L_.png', '26_L_.png', '1_L_.png', '31_L_.png', '9_L_.png', '23_L_.png', '7_L_.png', '41_L_.png', '11_L_.png', '20_L_.png')

# %%
imgStRList = []
i = 0
while(i<sizeStR):
    imStR = cv2.imread(pathStR+listingsStR[i])
    imgStRList.append(imStR)
    i+=1
#endwhile
print(len(imgStRList))

imgStLList = []
i = 0
while(i<sizeStL):
    imStL = cv2.imread(pathStL+listingsStL[i])
    imgStLList.append(imStL)
    i+=1
#endwhile
print(len(imgStLList))

print(imgStRList[0].shape)
print(imgStLList[0].shape)
# Out:
# 42
# 42
# (1200, 1600, 3)
# (1200, 1600, 3)

# %%
chessSqSize = 27
h, w = 7,6
patternSize = (h,w)
# prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
objp = np.zeros((w*h,3), np.float32)
objp[:,:2] = np.mgrid[0:h,0:w].T.reshape(-1,2)*chessSqSize
print(objp)

chessCriteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 26, 0.001)
findChessboardFlags = None
downScaleSize = (640,480)
# font
font = cv2.FONT_HERSHEY_SIMPLEX
# org
org = (50, 50)
# fontScale
fontScale = 1
# Blue color in BGR
color = (55, 10, 100)
# Line thickness of 2 px
thickness = 2
# Out:
# [[  0.   0.   0.]
#  [ 27.   0.   0.]
#  [ 54.   0.   0.]
#  [ 81.   0.   0.]
#  [108.   0.   0.]
#  [135.   0.   0.]
#  [162.   0.   0.]
#  [  0.  27.   0.]
#  [ 27.  27.   0.]
#  [ 54.  27.   0.]
#  [ 81.  27.   0.]
#  [108.  27.   0.]
#  [135.  27.   0.]
#  [162.  27.   0.]
#  [  0.  54.   0.]
#  [ 27.  54.   0.]
#  [ 54.  54.   0.]
#  [ 81.  54.   0.]
#  [108.  54.   0.]
#  [135.  54.   0.]
#  [162.  54.   0.]
#  [  0.  81.   0.]
#  [ 27.  81.   0.]
#  [ 54.  81.   0.]
#  [ 81.  81.   0.]
#  [108.  81.   0.]
#  [135.  81.   0.]
#  [162.  81.   0.]
#  [  0. 108.   0.]
#  [ 27. 108.   0.]
#  [ 54. 108.   0.]
#  [ 81. 108.   0.]
#  [108. 108.   0.]
#  [135. 108.   0.]
#  [162. 108.   0.]
#  [  0. 135.   0.]
#  [ 27. 135.   0.]
#  [ 54. 135.   0.]
#  [ 81. 135.   0.]
#  [108. 135.   0.]
#  [135. 135.   0.]
#  [162. 135.   0.]]

# %%
imgStLeftPoints = []
imgStRightPoints = []
objStPoints = []
stRightImage, stLeftImage, stRightImageGray, stLeftImageGray = None,None,None,None

j=0
while(j<sizeStR):
    print(f'getting: {j}...')
    imageSize = imgStLList[j].shape

    stLeftImageGray = cv2.cvtColor(imgStLList[j], cv2.COLOR_BGR2GRAY)
    stLeftImage = imgStLList[j].copy()
    stRightImageGray = cv2.cvtColor(imgStRList[j], cv2.COLOR_BGR2GRAY)
    stRightImage = imgStRList[j].copy()

    leftFound, leftCorners = cv2.findChessboardCorners(stLeftImageGray, patternSize, flags = findChessboardFlags)
    rightFound, rightCorners = cv2.findChessboardCorners(stRightImageGray, patternSize, flags = findChessboardFlags)

    if leftFound:
        cv2.cornerSubPix(stLeftImageGray, leftCorners, (11,11), (-1,-1), chessCriteria)
        print(f'Left = {str(leftFound)}: {j}')
    #endif

    if rightFound:
        cv2.cornerSubPix(stRightImageGray, rightCorners, (11,11), (-1,-1), chessCriteria)
        print(f'Right = {str(leftFound)}: {j}')
    #endif

    cv2.drawChessboardCorners(stLeftImage, patternSize, leftCorners, leftFound)
    cv2.drawChessboardCorners(stRightImage, patternSize, rightCorners, rightFound)
    cv2.putText(stLeftImage, f'{j}/{sizeStL}', org, font, fontScale, color, thickness, cv2.LINE_AA)
    cv2.putText(stRightImage, f'{j}/{sizeStR}', org, font, fontScale, color, thickness, cv2.LINE_AA)


    if leftFound and rightFound:
        cv2.putText(stLeftImage, 'Press a to accept, any other key to reject.', (50, 150), font, fontScale, color, thickness, cv2.LINE_AA)
        cv2.putText(stRightImage, 'Press a to accept, any other key to reject.', (50, 150), font, fontScale, color, thickness, cv2.LINE_AA)
        
        cv2.imshow("stl chess", cv2.resize(stLeftImage, downScaleSize))
        cv2.imshow("str chess", cv2.resize(stRightImage, downScaleSize))

        if cv2.waitKey(0) & 0xff == ord('a'):
            imgStLeftPoints.append(leftCorners)
            imgStRightPoints.append(rightCorners)
            objStPoints.append(objp)
            print(f'accepted: {j}')
        else:
            cv2.waitKey(200)
            print(f'rejected: {j}')
        #endif
    else:
        cv2.imshow("stl chess", cv2.resize(stLeftImage, downScaleSize))
        cv2.imshow("str chess", cv2.resize(stRightImage, downScaleSize))
        cv2.waitKey(200)
        print(f'auto rejected: {j}')
    #endif

    print('...........................')

    j+=1
#endwhile

cv2.destroyAllWindows()
# Out:
# getting: 0...
# Left = True: 0
# Right = True: 0
# accepted: 0
# ...........................
# getting: 1...
# Left = True: 1
# Right = True: 1
# accepted: 1
# ...........................
# getting: 2...
# Left = True: 2
# Right = True: 2
# accepted: 2
# ...........................
# getting: 3...
# Left = True: 3
# Right = True: 3
# accepted: 3
# ...........................
# getting: 4...
# Left = True: 4
# Right = True: 4
# accepted: 4
# ...........................
# getting: 5...
# Right = False: 5
# auto rejected: 5
# ...........................
# getting: 6...
# Left = True: 6
# Right = True: 6
# accepted: 6
# ...........................
# getting: 7...
# Left = True: 7
# Right = True: 7
# accepted: 7
# ...........................
# getting: 8...
# Right = False: 8
# auto rejected: 8
# ...........................
# getting: 9...
# Left = True: 9
# Right = True: 9
# accepted: 9
# ...........................
# getting: 10...
# Left = True: 10
# Right = True: 10
# accepted: 10
# ...........................
# getting: 11...
# Left = True: 11
# Right = True: 11
# accepted: 11
# ...........................
# getting: 12...
# Left = True: 12
# Right = True: 12
# accepted: 12
# ...........................
# getting: 13...
# Left = True: 13
# Right = True: 13
# accepted: 13
# ...........................
# getting: 14...
# Left = True: 14
# Right = True: 14
# accepted: 14
# ...........................
# getting: 15...
# Left = True: 15
# Right = True: 15
# accepted: 15
# ...........................
# getting: 16...
# Left = True: 16
# Right = True: 16
# accepted: 16
# ...........................
# getting: 17...
# Left = True: 17
# Right = True: 17
# accepted: 17
# ...........................
# getting: 18...
# Left = True: 18
# Right = True: 18
# accepted: 18
# ...........................
# getting: 19...
# Left = True: 19
# Right = True: 19
# accepted: 19
# ...........................
# getting: 20...
# Left = True: 20
# Right = True: 20
# accepted: 20
# ...........................
# getting: 21...
# Left = True: 21
# Right = True: 21
# accepted: 21
# ...........................
# getting: 22...
# Left = True: 22
# Right = True: 22
# accepted: 22
# ...........................
# getting: 23...
# Left = True: 23
# Right = True: 23
# accepted: 23
# ...........................
# getting: 24...
# Left = True: 24
# Right = True: 24
# accepted: 24
# ...........................
# getting: 25...
# Left = True: 25
# Right = True: 25
# accepted: 25
# ...........................
# getting: 26...
# Left = True: 26
# Right = True: 26
# rejected: 26
# ...........................
# getting: 27...
# Left = True: 27
# Right = True: 27
# accepted: 27
# ...........................
# getting: 28...
# Left = True: 28
# Right = True: 28
# accepted: 28
# ...........................
# getting: 29...
# Left = True: 29
# Right = True: 29
# accepted: 29
# ...........................
# getting: 30...
# Left = True: 30
# Right = True: 30
# rejected: 30
# ...........................
# getting: 31...
# Left = True: 31
# auto rejected: 31
# ...........................
# getting: 32...
# auto rejected: 32
# ...........................
# getting: 33...
# Left = True: 33
# Right = True: 33
# accepted: 33
# ...........................
# getting: 34...
# Left = True: 34
# Right = True: 34
# accepted: 34
# ...........................
# getting: 35...
# Left = True: 35
# Right = True: 35
# accepted: 35
# ...........................
# getting: 36...
# auto rejected: 36
# ...........................
# getting: 37...
# Left = True: 37
# Right = True: 37
# accepted: 37
# ...........................
# getting: 38...
# Left = True: 38
# Right = True: 38
# accepted: 38
# ...........................
# getting: 39...
# Right = False: 39
# auto rejected: 39
# ...........................
# getting: 40...
# Left = True: 40
# Right = True: 40
# accepted: 40
# ...........................
# getting: 41...
# Left = True: 41
# Right = True: 41
# accepted: 41
# ...........................

# %%
cv2.destroyAllWindows()

# %%
print(len(imgStLeftPoints))
print(len(imgStRightPoints))
# Out:
# 34
# 34

# %%
# stCriteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.1)
stCriteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.001)
# stFlags = cv2.CALIB_FIX_ASPECT_RATIO | cv2.CALIB_ZERO_TANGENT_DIST | cv2.CALIB_SAME_FOCAL_LENGTH | cv2.CALIB_RATIONAL_MODEL | cv2.CALIB_FIX_K3 | cv2.CALIB_FIX_K4 | cv2.CALIB_FIX_K5
stFlags = cv2.CALIB_FIX_INTRINSIC
retS, MLS, dLS, MRS, dRS, R, T, E, F = cv2.stereoCalibrate(
    objStPoints,
    imgStLeftPoints,
    imgStRightPoints,
    mtxL,
    distL,
    mtxR,
    distR,
    stLeftImageGray.shape[::-1],
    stCriteria,
    stFlags
)

print('ret - stereo ', retS)

print(' MRS -> ',MRS,2*'\n','mtxR -> ',mtxR,2*'\n','MLS -> ',MLS,2*'\n','mtxL -> ',mtxL)
print(' Rotational -> \n',R,2*'\n','Translational -> \n',T,2*'\n','Essential -> \n',E,2*'\n','Fundamental -> \n',F)
# Out:
# ret - stereo  0.9272042264235885
#  MRS ->  [[865.01234245   0.         787.26088878]
#  [  0.         865.54856289 601.19468339]
#  [  0.           0.           1.        ]]
#
#  mtxR ->  [[865.01234245   0.         787.26088878]
#  [  0.         865.54856289 601.19468339]
#  [  0.           0.           1.        ]]
#
#  MLS ->  [[854.04143235   0.         814.66070348]
#  [  0.         853.99709956 589.73557822]
#  [  0.           0.           1.        ]]
#
#  mtxL ->  [[854.04143235   0.         814.66070348]
#  [  0.         853.99709956 589.73557822]
#  [  0.           0.           1.        ]]
#  Rotational ->
#  [[ 9.99773608e-01  4.26290526e-05  2.12774798e-02]
#  [ 3.78233756e-04  9.99804378e-01 -1.97753138e-02]
#  [-2.12741604e-02  1.97788847e-02  9.99578014e-01]]
#
#  Translational ->
#  [[310.03114871]
#  [ -1.00881436]
#  [  9.28381869]]
#
#  Essential ->
#  [[ 1.79502250e-02 -9.30195579e+00 -8.24798229e-01]
#  [ 1.58773693e+01 -6.13167458e+00 -3.09702784e+02]
#  [ 1.12585022e+00  3.09970543e+02 -6.10949823e+00]]
#
#  Fundamental ->
#  [[-6.70516667e-09  3.47485348e-06 -1.78065473e-03]
#  [-5.92719332e-06  2.28913913e-06  1.02218999e-01]
#  [ 3.20489266e-03 -1.04274288e-01  1.00000000e+00]]

# %%
np.save(calibParams+'R.npy', R)
np.save(calibParams+'T.npy', T)
np.save(calibParams+'E.npy', E)
np.save(calibParams+'F.npy', F)

np.save(calibParams+'MLS.npy', MLS)
np.save(calibParams+'dLS.npy', dLS)
np.save(calibParams+'MRS.npy', MRS)
np.save(calibParams+'dRS.npy', dRS)

# %%
rectifyScale = 0 # if 0 image croped, if 1 image nor croped
RL, RR, PL, PR, Q, roiL, roiR = cv2.stereoRectify(MLS, dLS, MRS, dRS, stLeftImageGray.shape[::-1], R, T, rectifyScale) # last paramater is alpha, if 0= croped, if 1= not croped
# initUndistortRectifyMap function
leftStereoMap = cv2.initUndistortRectifyMap(MLS, dLS, RL, PL, stLeftImageGray.shape[::-1], cv2.CV_16SC2)   # cv2.CV_16SC2 this format enables us the programme to work faster
rightStereoMap = cv2.initUndistortRectifyMap(MRS, dRS, RR, PR, stRightImageGray.shape[::-1], cv2.CV_16SC2)

# %%
np.save(calibParams+'RL.npy', RL)
np.save(calibParams+'RR.npy', RR)
np.save(calibParams+'PL.npy', PL)
np.save(calibParams+'PR.npy', PR)
np.save(calibParams+'Q.npy', Q)

# %%
def drawLines(img):
    # img = image.copy()
    y,count = 0,0
    while(count<40):
        img = cv2.line(img, (0,50+y), (img.shape[1],50+y), (y,count*2,y), 2)
        y+=30
        count+=1
    #endwhile
    return cv2.resize(img, (640,480))
#enddef

# %%
picNum = '1'
rectPath = "../rectified/"
frameL = cv2.imread(pathTestL+picNum+'_L_.png')
frameR = cv2.imread(pathTestR+picNum+'_R_.png')

leftNice = cv2.remap(frameL,leftStereoMap[0],leftStereoMap[1], cv2.INTER_LANCZOS4, cv2.BORDER_CONSTANT, 0)  # Rectify the image using the kalibration parameters founds during the initialisation
rightNice = cv2.remap(frameR,rightStereoMap[0],rightStereoMap[1], cv2.INTER_LANCZOS4, cv2.BORDER_CONSTANT, 0)

frameLCpy = frameL.copy()
frameRCpy = frameR.copy()

xr,yr,wr,hr = roiR
xl,yl,wl,hl = roiL

rightImgRemapCp = rightNice.copy()
leftImgRemapCp = leftNice.copy()

cv2.imshow('R', drawLines(frameRCpy))
cv2.imshow('L', drawLines(frameLCpy))
cv2.imshow('R rect', drawLines(rightImgRemapCp))
cv2.imshow('L rect', drawLines(leftImgRemapCp))
cv2.waitKey(0)

origLR = np.concatenate((frameLCpy, frameRCpy), axis=1)
cv2.imwrite(rectPath+picNum+'_orig.png', origLR)
rectLR = np.concatenate((leftImgRemapCp, rightImgRemapCp), axis=1)
cv2.imwrite(rectPath+picNum+'_rect.png', rectLR)
cv2.destroyAllWindows()

# %%
grayR = cv2.cvtColor(rightNice,cv2.COLOR_BGR2GRAY)
grayL = cv2.cvtColor(leftNice,cv2.COLOR_BGR2GRAY)

# Create StereoSGBM and prepare all parameters
window_size = 7
min_disp = 1
num_disp = (16*16)+1-min_disp
left_matcher = cv2.StereoSGBM_create(minDisparity = min_disp,
    numDisparities = num_disp,
    blockSize = window_size,
    uniquenessRatio = 10,
    speckleWindowSize = 100,
    speckleRange = 32,
    disp12MaxDiff = 5,
    P1 = 8*3*window_size**2,
    P2 = 32*3*window_size**2)

# Used for the filtered image
right_matcher = cv2.ximgproc.createRightMatcher(left_matcher) # Create another stereo for right this time

# WLS FILTER Parameters
lmbda = 80000
sigma = 1.8
visual_multiplier = 1.0

wls_filter = cv2.ximgproc.createDisparityWLSFilter(matcher_left=left_matcher)
wls_filter.setLambda(lmbda)
wls_filter.setSigmaColor(sigma)

dispL = left_matcher.compute(grayL,grayR)
dispR = right_matcher.compute(grayR,grayL)
dispL = np.int16(dispL)
dispR = np.int16(dispR)

filteredImg = wls_filter.filter(dispL, grayL, None, dispR)  # important to put "imgL" here!!!
filteredImg = cv2.normalize(src=filteredImg, dst=filteredImg, beta=0, alpha=255, norm_type=cv2.NORM_MINMAX);
filteredImg = np.uint8(filteredImg)

fil = cv2.resize(filteredImg, (640, 480))
cv2.imshow('filteredImg',fil)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.destroyAllWindows()
